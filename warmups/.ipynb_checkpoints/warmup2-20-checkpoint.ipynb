# %%
from matplotlib import pyplot as plt 
import math
import numpy as np

fig, ax = plt.subplots(1, 1) 
z = np.linspace(0.01,5)
t = np.linspace(-1,1)


ax.set(xlabel = r"$z$", 
       ylabel = r"$f(z)$")

ax.plot(z, -1*np.log(z))
ax.plot(t, -1*np.log(1-t))
# Out:
# /var/folders/vk/xj75_42s2sg_qkc3_dxpnbww0000gn/T/ipykernel_74421/3671346004.py:14: RuntimeWarning: divide by zero encountered in log
#   ax.plot(t, -1*np.log(1-t))
